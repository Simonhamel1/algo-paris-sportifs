# %%
import os
from dotenv import load_dotenv
import pandas as pd
import requests
import time

load_dotenv()

API_KEY = os.getenv("ODDS_API_KEY")  # Assumes your API key is stored in an environment variable

def get_remaining_quotas(api_key):
    url = "https://api.the-odds-api.com/v4/sports"
    params = {"apiKey": api_key}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        # Quota info is in response headers
        quota_used = response.headers.get("x-requests-used")
        quota_remaining = response.headers.get("x-requests-remaining")
        return quota_used, quota_remaining
    else:
        raise Exception(f"API request failed: {response.status_code} {response.text}")

if API_KEY:
    used, remaining = get_remaining_quotas(API_KEY)
    print(f"API quota used: {used}, remaining: {remaining}")
else:
    print("ODDS_API_KEY environment variable not set.")
# Out:
# API quota used: 0, remaining: 500

# %%
"""
Script pour récupérer tous les paris sur les plateformes françaises via The Odds API (v4).

Ce script récupère toutes les cotes disponibles sur les bookmakers français
pour différents sports et marchés, sans filtre sur les valeurs de cotes.

Principales fonctionnalités :

    • Récupère les cotes pour tous les sports disponibles
    • Filtre uniquement les bookmakers français
    • Inclut plusieurs types de marchés (h2h, totals, spreads, etc.)
    • Exporte les données en CSV pour analyse

Utilisation :

    Définissez la variable `API_KEY` ci-dessous avec votre clé Odds API valide. Puis lancez :

        python3 odds_filter_script.py

Dépendances :

    pip install requests pandas

Note :
    Ce script est prévu pour une exécution locale avec un accès internet.
"""

import os
from typing import Dict, List, Optional, Any
from datetime import datetime

import requests
import pandas as pd

# ============================ Configuration ============================

# Remplacez ceci par votre propre clé API
API_KEY = "5bb24e9151caf14c896925a570220a78"

# Liste des bookmakers français connus
FRENCH_BOOKMAKERS = [
    "parionssport",
    "betclic",
    "unibet_fr",
    "zebet",
    "winamax",
    "pmu",
    "bwin_fr",
    "vbet_fr",
    "netbet_fr"
]

# Codes régionaux pour les bookmakers français/européens
REGION: str = "eu"

# Types de marchés à récupérer
MARKETS = "h2h,spreads,totals"

# =========================== Fonctions Utilitaires ===========================

def get_available_sports(api_key: str) -> List[Dict[str, Any]]:
    """Récupère la liste de tous les sports disponibles.
    
    Args:
        api_key: Votre clé Odds API.
        
    Returns:
        Liste des sports avec leurs détails.
    """
    url = "https://api.the-odds-api.com/v4/sports/"
    params = {"apiKey": api_key}
    try:
        response = requests.get(url, params=params, timeout=30)
        response.raise_for_status()
        return response.json()
    except Exception as exc:
        print(f"Erreur lors de la récupération des sports : {exc}")
        return []

def fetch_odds(
    api_key: str,
    sport_key: str,
    region: str = REGION,
    markets: str = MARKETS,
    odds_format: str = "decimal",
) -> List[Dict[str, Any]]:
    """Récupère les cotes pour un sport donné via The Odds API.
    
    Args:
        api_key: Votre clé Odds API.
        sport_key: Identifiant du sport (ex : 'soccer_france_ligue_one').
        region: Code(s) régionaux comme 'eu', 'us', 'uk'.
        markets: Marchés à récupérer (ex : 'h2h,totals,spreads').
        odds_format: Format des cotes ('decimal' ou 'american').
        
    Returns:
        Une liste de dictionnaires d'événements retournés par l'API.
    """
    url = f"https://api.the-odds-api.com/v4/sports/{sport_key}/odds/"
    params: Dict[str, Any] = {
        "apiKey": api_key,
        "regions": region,
        "markets": markets,
        "oddsFormat": odds_format,
        "includeLinks": "true",
        "includeSids": "true",
    }
    
    try:
        response = requests.get(url, params=params, timeout=30)
        if response.status_code == 404:
            return []
        response.raise_for_status()
        return response.json()
    except Exception as exc:
        print(f"Erreur pour {sport_key} : {exc}")
        return []

def _deep_link(event: Dict, bookmaker: Dict, market: Dict, outcome: Dict) -> Optional[str]:
    """Retourne le lien le plus profond selon la hiérarchie de l'API."""
    return (
        outcome.get("link")
        or market.get("link")
        or bookmaker.get("link")
        or event.get("link")
    )

def extract_all_bookmaker_odds(event: Dict, french_only: bool = True) -> List[Dict[str, Any]]:
    """Extrait toutes les cotes disponibles pour un événement.
    
    Args:
        event: Dictionnaire d'événement de l'API.
        french_only: Si True, filtre uniquement les bookmakers français.
        
    Returns:
        Liste de dictionnaires avec les informations de paris.
    """
    results: List[Dict[str, Any]] = []
    home_team = event.get("home_team", "")
    away_team = event.get("away_team", "")
    
    for bookmaker in event.get("bookmakers", []):
        book_key = bookmaker.get("key", "")
        book_title = bookmaker.get("title", book_key)
        
        # Filtre les bookmakers français si demandé
        if french_only and book_key not in FRENCH_BOOKMAKERS:
            continue
        
        for market in bookmaker.get("markets", []):
            market_key = market.get("key", "")
            
            for outcome in market.get("outcomes", []):
                name = outcome.get("name", "")
                price = outcome.get("price")
                point = outcome.get("point")
                
                try:
                    price_val = float(price)
                except (TypeError, ValueError):
                    continue
                
                # Détermine le type d'issue
                outcome_type = ""
                if market_key == "h2h":
                    if name.lower() in {"draw", "tie", "egalité"}:
                        outcome_type = "Nul"
                    elif name == home_team:
                        outcome_type = "Domicile"
                    elif name == away_team:
                        outcome_type = "Extérieur"
                    else:
                        outcome_type = name
                elif market_key == "totals":
                    outcome_type = f"{name} {point if point else ''}"
                elif market_key == "spreads":
                    outcome_type = f"{name} ({point if point else ''})"
                else:
                    outcome_type = name
                
                results.append({
                    "event_id": event.get("id"),
                    "sport_key": event.get("sport_key"),
                    "sport_title": event.get("sport_title", ""),
                    "commence_time": event.get("commence_time"),
                    "home_team": home_team,
                    "away_team": away_team,
                    "bookmaker": book_key,
                    "bookmaker_title": book_title,
                    "market": market_key,
                    "outcome_name": name,
                    "outcome_type": outcome_type,
                    "odds": price_val,
                    "point": point,
                    "link": _deep_link(event, bookmaker, market, outcome),
                })
    
    return results

def collect_all_french_odds(api_key: str) -> pd.DataFrame:
    """Récupère toutes les cotes françaises pour tous les sports disponibles.
    
    Args:
        api_key: Clé Odds API.
        
    Returns:
        DataFrame pandas avec toutes les cotes des bookmakers français.
    """
    print("Récupération de la liste des sports disponibles...")
    sports = get_available_sports(api_key)
    
    if not sports:
        print("Aucun sport disponible.")
        return pd.DataFrame()
    
    print(f"{len(sports)} sports trouvés.")
    
    records: List[Dict[str, Any]] = []
    
    for sport in sports:
        sport_key = sport.get("key")
        sport_title = sport.get("title", sport_key)
        
        print(f"Traitement de {sport_title} ({sport_key})...")
        
        try:
            events = fetch_odds(api_key, sport_key)
            
            if not events:
                continue
            
            event_count = 0
            for event in events:
                odds_data = extract_all_bookmaker_odds(event, french_only=True)
                records.extend(odds_data)
                if odds_data:
                    event_count += 1
            
            if event_count > 0:
                print(f"  → {event_count} événement(s) avec bookmakers français")
                
        except Exception as exc:
            print(f"  ✗ Erreur : {exc}")
            continue
    
    df = pd.DataFrame(records)
    
    if not df.empty:
        # Conversion de la date
        df['commence_time'] = pd.to_datetime(df['commence_time'])
        df = df.sort_values(['commence_time', 'sport_key', 'event_id', 'bookmaker', 'market'])
        df = df.reset_index(drop=True)
    
    return df

def main() -> None:
    """Point d'entrée du script."""
    if not API_KEY:
        print("Aucune clé API n'est configurée. Veuillez définir API_KEY dans le script.")
        return
    
    print("=" * 60)
    print("Récupération des paris sur les plateformes françaises")
    print("=" * 60)
    print()
    
    df = collect_all_french_odds(API_KEY)
    
    if df.empty:
        print("\nAucun pari français trouvé.")
        return
    
    print("\n" + "=" * 60)
    print(f"Total : {len(df)} paris récupérés")
    print("=" * 60)
    
    # Statistiques
    print(f"\nNombre d'événements uniques : {df['event_id'].nunique()}")
    print(f"Nombre de bookmakers : {df['bookmaker'].nunique()}")
    print(f"Nombre de sports : {df['sport_key'].nunique()}")
    
    print("\nBookmakers présents :")
    for bm in df['bookmaker_title'].unique():
        count = len(df[df['bookmaker_title'] == bm])
        print(f"  • {bm} : {count} paris")
    
    print("\nSports couverts :")
    for sport in df['sport_title'].unique():
        count = df[df['sport_title'] == sport]['event_id'].nunique()
        print(f"  • {sport} : {count} événement(s)")
    
    # Sauvegarde
    os.makedirs("./data", exist_ok=True)
    output_file = "./data/paris-sportifs-francais.csv"
    df.to_csv(output_file, index=False)
    
    print(f"\n✓ Résultats enregistrés dans '{output_file}'")
    
    # Aperçu des données
    print("\nAperçu des premières lignes :")
    print(df.head(10).to_string(index=False))

if __name__ == "__main__":
    main()
# Out:
# ...
# Récupération des paris sur les plateformes françaises
# ...
#
# Récupération de la liste des sports disponibles...
# 67 sports trouvés.
# Traitement de CFL (americanfootball_cfl)...
# Traitement de NCAAF (americanfootball_ncaaf)...
# Traitement de NCAAF Championship Winner (americanfootball_ncaaf_championship_winner)...
# Erreur pour americanfootball_ncaaf_championship_winner : 422 Client Error: Unprocessable Entity for url: https://api.the-odds-api.com/v4/sports/americanfootball_ncaaf_championship_winner/odds/?apiKey=5bb24e9151caf14c896925a570220a78&regions=eu&markets=h2h%2Cspreads%2Ctotals&oddsFormat=decimal&includeLinks=true&includeSids=true
# Traitement de NFL (americanfootball_nfl)...
#   → 15 événement(s) avec bookmakers français
# Traitement de NFL Super Bowl Winner (americanfootball_nfl_super_bowl_winner)...
# ...

# %%
# Charger les données
data_paris_sportifs = pd.read_csv("./data/paris-sportifs-francais.csv")

# Garder uniquement le marché h2h (3 issues possibles selon le sport)
h2h = data_paris_sportifs[data_paris_sportifs["market"] == "h2h"].copy()

# Pivot des cotes
idx_cols = ["event_id", "sport_key", "sport_title", "commence_time", "home_team", "away_team", "bookmaker", "bookmaker_title"]
pivot_odds = (
    h2h.pivot_table(index=idx_cols, columns="outcome_type", values="odds", aggfunc="first")
       .reset_index()
)

# Pivot des liens
pivot_links = (
    h2h.pivot_table(index=idx_cols, columns="outcome_type", values="link", aggfunc="first")
       .reset_index()
       .rename(columns={"Domicile": "Domicile_link", "Nul": "Nul_link", "Extérieur": "Extérieur_link"})
)

# Fusion
paris_3cotes = pivot_odds.merge(pivot_links, on=idx_cols, how="left")

# Renommer les colonnes
paris_3cotes = paris_3cotes.rename(columns={
    "Domicile": "home_odds",
    "Nul": "draw_odds",
    "Extérieur": "away_odds",
    "Domicile_link": "home_link",
    "Nul_link": "draw_link",
    "Extérieur_link": "away_link",
})

# Nombre de cotes disponibles par événement/bookmaker (2 pour NFL, 3 pour soccer, etc.)
paris_3cotes["nb_cotes"] = paris_3cotes[["home_odds", "draw_odds", "away_odds"]].notna().sum(axis=1)

# Nettoyage/tri
paris_3cotes["commence_time"] = pd.to_datetime(paris_3cotes["commence_time"])
paris_3cotes = paris_3cotes.sort_values(["commence_time", "sport_key", "event_id", "bookmaker_title"]).reset_index(drop=True)

# Petit récap du nombre d'issues présentes dans le dataset
resume_issues = (
    h2h["outcome_type"].value_counts()
      .rename_axis("pari")
      .reset_index(name="nombre")
      .sort_values("pari")
)
print("Nombre d'issues par type de pari (toutes compétitions confondues) :")
print(resume_issues.to_string(index=False))

# Affichage principal avec les 3 cotes (si dispo) et leur nombre
paris_3cotes
# Out:
# Nombre d'issues par type de pari (toutes compétitions confondues) :
#      pari  nombre
#  Domicile     250
# Extérieur     250
#       Nul     206
# outcome_type                          event_id                     sport_key  \
# 0             08b73c02af76a1a4c563ad1f30754cbb    soccer_greece_super_league
# 1             31b12e50e5d7c037de080328b4778693  soccer_finland_veikkausliiga
# 2             cef7f41338151f1842b075e0a7b57a16  soccer_finland_veikkausliiga
# 3             c74f97d45a51dec401723c4a4d270744          soccer_italy_serie_a
# 4             8baa13603330e6efab170a7293e0c93f     soccer_sweden_allsvenskan
# ..                                         ...                           ...
# 245           4fcee6abffe1e7a7ae477136f92dad6f       soccer_france_ligue_one
# 246           e15977ee82f12b17456174c201b2d01d    soccer_greece_super_league
# 247           7fce93e78c98ee117f5a44ab08c7fd34    soccer_greece_super_league
# ...

# %%
paris_3cotes['combined_product'] = paris_3cotes[['home_odds', 'draw_odds', 'away_odds']].prod(axis=1, skipna=True).clip(lower=2)
paris_3cotes.sort_values('combined_product', ascending=False)[['home_odds', 'draw_odds', 'away_odds', 'combined_product']]
# Out:
# outcome_type  home_odds  draw_odds  away_odds  combined_product
# 195                1.01       21.0      27.00          572.6700
# 199               25.00       14.0       1.02          357.0000
# 50                 1.02        9.8      28.50          284.8860
# 206                1.04        8.7      26.00          235.2480
# 205               16.50        8.2       1.07          144.7710
# ..                  ...        ...        ...               ...
# 190                1.53        NaN       2.15            3.2895
# 171                1.59        NaN       2.04            3.2436
# 192                1.61        NaN       2.00            3.2200
# 174                1.65        NaN       1.95            3.2175
# 176                1.73        NaN       1.85            3.2005
#
# [250 rows x 4 columns]
