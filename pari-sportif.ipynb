# %%
import os
from dotenv import load_dotenv
import pandas as pd
import requests
import time

load_dotenv()

API_KEY = os.getenv("ODDS_API_KEY")  # Assumes your API key is stored in an environment variable

def get_remaining_quotas(api_key):
    url = "https://api.the-odds-api.com/v4/sports"
    params = {"apiKey": api_key}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        # Quota info is in response headers
        quota_used = response.headers.get("x-requests-used")
        quota_remaining = response.headers.get("x-requests-remaining")
        return quota_used, quota_remaining
    else:
        raise Exception(f"API request failed: {response.status_code} {response.text}")

if API_KEY:
    used, remaining = get_remaining_quotas(API_KEY)
    print(f"API quota used: {used}, remaining: {remaining}")
else:
    print("ODDS_API_KEY environment variable not set.")
# Out:
# API quota used: 23, remaining: 477

# %%
"""
Script pour récupérer et filtrer les cotes avec The Odds API (v4).

Ce script montre comment obtenir les cotes 1N2 (domicile/nul/extérieur)
pour un ou plusieurs sports, identifier les événements où les trois issues
ont des cotes proches d'une valeur cible, et assembler les résultats dans un DataFrame pandas.

Principales fonctionnalités :

    • Utilise la clé API fournie pour authentifier les requêtes vers The Odds API.
    • Demande les cotes décimales pour le marché h2h (1N2) et inclut les liens profonds
        (`includeLinks=true`) et les identifiants de source (`includeSids=true`).
    • Extrait le meilleur prix disponible pour chaque issue par bookmaker et
        sélectionne le lien le plus profond dans la hiérarchie issue → marché →
        bookmaker → événement, comme recommandé par la documentation de The Odds API.
    • Filtre les bookmakers dont les cotes pour les trois issues sont toutes dans
        une tolérance configurable autour d'une valeur cible (par défaut 3.0 ± 0.6) et trie
        les résultats par le produit des trois cotes.

Utilisation :

    Définissez la variable `API_KEY` ci-dessous avec votre clé Odds API valide. Puis lancez :

            python3 odds_filter_script.py

    Par défaut, le script interroge la Premier League anglaise (clé de sport
    'soccer_epl'). Vous pouvez changer `SPORT_KEYS` pour une liste d'autres sports
    (ex : ['americanfootball_nfl', 'basketball_nba']) ou utiliser l'endpoint
    '/v4/sports' pour découvrir les clés disponibles.

Dépendances :

    pip install requests pandas

Note :
    Ce script est prévu pour une exécution locale. Les appels réseau sont désactivés
    dans cet environnement de chat, donc il ne fonctionnera pas ici.
    Enregistrez-le sur votre machine et exécutez-le avec un accès internet.
"""

import os
from typing import Dict, List, Optional, Any, Tuple

import requests
import pandas as pd

# ============================ Configuration ============================

# Remplacez ceci par votre propre clé API. Ne partagez jamais de clé réelle publiquement.

# Liste des clés de sport à interroger. 'soccer_epl' pour la Premier League,
# 'upcoming' pour un mélange de sports, ou appelez /v4/sports pour en découvrir d'autres.
SPORT_KEYS: List[str] = ["upcoming"]

# Cote cible et tolérance. Le script sélectionne les événements où les cotes domicile,
# nul et extérieur sont toutes dans [TARGET - TOL, TARGET + TOL].
TARGET: float = 3.0
TOL: float = 0.6

# Codes régionaux pour les bookmakers. 'eu' retourne les bookmakers européens.
REGION: str = "eu"

# =========================== Fonctions Utilitaires ===========================

def fetch_odds(
        api_key: str,
        sport_key: str,
        region: str = REGION,
        markets: str = "h2h",
        odds_format: str = "decimal",
        include_links: bool = True,
        include_sids: bool = True,
) -> List[Dict[str, Any]]:
        """Récupère les cotes pour un sport donné via The Odds API.

        Args:
                api_key: Votre clé Odds API.
                sport_key: Identifiant du sport (ex : 'soccer_epl').
                region: Code(s) régionaux comme 'eu', 'us', 'uk'. Séparez par des virgules pour plusieurs.
                markets: Marché ; 'h2h' retourne les cotes 1N2 pour le foot.
                odds_format: Format des cotes ('decimal' ou 'american').
                include_links: Inclure les liens profonds (ajoute includeLinks=true).
                include_sids: Inclure les IDs de source (ajoute includeSids=true).

        Returns:
                Une liste de dictionnaires d'événements retournés par l'API.
        """
        url = f"https://api.the-odds-api.com/v4/sports/{sport_key}/odds/"
        params: Dict[str, Any] = {
                "apiKey": api_key,
                "regions": region,
                "markets": markets,
                "oddsFormat": odds_format,
        }
        if include_links:
                params["includeLinks"] = "true"
        if include_sids:
                params["includeSids"] = "true"
        response = requests.get(url, params=params, timeout=30)
        if response.status_code == 404:
                # Sport non disponible ou hors saison
                return []
        response.raise_for_status()
        return response.json()

def _deep_link(event: Dict, bookmaker: Dict, market: Dict, outcome: Dict) -> Optional[str]:
        """Retourne le lien le plus profond selon la hiérarchie de l'API.

        Ordre recommandé : outcome.link → market.link → bookmaker.link → event.link

        Args:
                event: Dictionnaire d'événement pouvant contenir un 'link'.
                bookmaker: Dictionnaire bookmaker pouvant contenir un 'link'.
                market: Dictionnaire marché pouvant contenir un 'link'.
                outcome: Dictionnaire issue pouvant contenir un 'link'.

        Returns:
                Le premier lien non vide trouvé ou None.
        """
        return (
                outcome.get("link")
                or market.get("link")
                or bookmaker.get("link")
                or event.get("link")
        )

def extract_bookmaker_odds(event: Dict) -> List[Dict[str, Any]]:
        """Extrait les meilleures cotes domicile/nul/extérieur et liens par bookmaker pour un événement.

        Args:
                event: Dictionnaire d'événement de l'API, contenant bookmakers et marchés.

        Returns:
                Une liste où chaque élément correspond à un bookmaker proposant les trois issues.
                Chaque élément contient les cotes et liens profonds.
        """
        results: List[Dict[str, Any]] = []
        home_team = event.get("home_team")
        away_team = event.get("away_team")
        for bookmaker in event.get("bookmakers", []):
                book_key = bookmaker.get("key")
                book_title = bookmaker.get("title", book_key)
                for market in bookmaker.get("markets", []):
                        if market.get("key") != "h2h":
                                continue
                        odds_map: Dict[str, float] = {}
                        link_map: Dict[str, Optional[str]] = {}
                        for outcome in market.get("outcomes", []):
                                name = outcome.get("name", "")
                                price = outcome.get("price")
                                if name.lower() in {"draw", "tie", "egalité"}:
                                        key = "draw"
                                elif name == home_team:
                                        key = "home"
                                elif name == away_team:
                                        key = "away"
                                else:
                                        continue
                                try:
                                        price_val = float(price)
                                except (TypeError, ValueError):
                                        continue
                                odds_map[key] = price_val
                                link_map[key] = _deep_link(event, bookmaker, market, outcome)
                        if len(odds_map) == 3:
                                results.append(
                                        {
                                                "event_id": event.get("id"),
                                                "sport_key": event.get("sport_key"),
                                                "commence_time": event.get("commence_time"),
                                                "home_team": home_team,
                                                "away_team": away_team,
                                                "bookmaker": book_key,
                                                "bookmaker_title": book_title,
                                                "home_odds": odds_map["home"],
                                                "draw_odds": odds_map["draw"],
                                                "away_odds": odds_map["away"],
                                                "home_link": link_map["home"],
                                                "draw_link": link_map["draw"],
                                                "away_link": link_map["away"],
                                        }
                                )
        return results

def find_events_with_target_odds(
        api_key: str,
        sport_keys: List[str],
        target: float = TARGET,
        tol: float = TOL,
        region: str = REGION,
) -> pd.DataFrame:
        """Récupère et filtre les offres bookmakers proches d'une cote cible.

        Args:
                api_key: Clé Odds API.
                sport_keys: Liste des identifiants de sport à interroger.
                target: Cote souhaitée autour de laquelle les trois issues doivent se situer.
                tol: Tolérance autour de la cote cible.
                region: Code(s) régionaux pour les bookmakers (ex : 'eu').

        Returns:
                Un DataFrame pandas avec une ligne par (événement, bookmaker) répondant aux critères.
                Colonnes : équipes, cotes, liens profonds et produit des cotes pour le tri.
        """
        records: List[Dict[str, Any]] = []
        for sport_key in sport_keys:
                try:
                        events = fetch_odds(api_key, sport_key, region=region)
                except Exception as exc:
                        print(f"Erreur lors de la récupération des cotes pour {sport_key} : {exc}")
                        continue
                for event in events:
                        for rec in extract_bookmaker_odds(event):
                                if (
                                        abs(rec["home_odds"] - target) <= tol
                                        and abs(rec["draw_odds"] - target) <= tol
                                        and abs(rec["away_odds"] - target) <= tol
                                ):
                                        rec["combined_product"] = (
                                                rec["home_odds"] * rec["draw_odds"] * rec["away_odds"]
                                        )
                                        records.append(rec)
        df = pd.DataFrame(records)
        if not df.empty:
                df = df.sort_values("combined_product", ascending=False).reset_index(drop=True)
        return df

def main() -> None:
        """Point d'entrée du script. Récupère les cotes, filtre et affiche le résultat."""
        if not API_KEY:
                print("Aucune clé API n'est configurée. Veuillez définir API_KEY dans le script.")
                return
        if not SPORT_KEYS:
                print("Aucune clé de sport fournie. Spécifiez au moins un sport.")
                return
        df = find_events_with_target_odds(API_KEY, SPORT_KEYS, TARGET, TOL, REGION)
        if df.empty:
                print("Aucun événement correspondant aux critères n'a été trouvé.")
        else:
                with pd.option_context('display.max_columns', None):
                        print(df.to_string(index=False))
                df.to_csv("./data/data-paris-sportifs.csv", index=False)
                print("\nLes résultats ont été enregistrés dans le fichier 'data-paris-sportifs.csv'.")

if __name__ == "__main__":
        main()
# Out:
#                         event_id                sport_key        commence_time           home_team           away_team     bookmaker bookmaker_title  home_odds  draw_odds  away_odds                                                                                                                                   home_link                                                                                                                                   draw_link                                                                                                                                   away_link  combined_product
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza     matchbook       Matchbook       2.90       3.25       2.84                                                            https://www.matchbook.com/events/soccer/brazil/brazil-serie-a/31313378613000061/                                                            https://www.matchbook.com/events/soccer/brazil/brazil-serie-a/31313378613000061/                                                            https://www.matchbook.com/events/soccer/brazil/brazil-serie-a/31313378613000061/         26.767000
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza betfair_ex_eu         Betfair       2.90       3.25       2.82                                                                           https://www.betfair.com/exchange/plus/football/market/1.248382810                                                                           https://www.betfair.com/exchange/plus/football/market/1.248382810                                                                           https://www.betfair.com/exchange/plus/football/market/1.248382810         26.578500
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos betfair_ex_eu         Betfair       2.58       3.10       3.30                                                                           https://www.betfair.com/exchange/plus/football/market/1.248383132                                                                           https://www.betfair.com/exchange/plus/football/market/1.248383132                                                                           https://www.betfair.com/exchange/plus/football/market/1.248383132         26.393400
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos     matchbook       Matchbook       2.58       3.10       3.30                                                            https://www.matchbook.com/events/soccer/brazil/brazil-serie-a/31313435410600061/                                                            https://www.matchbook.com/events/soccer/brazil/brazil-serie-a/31313435410600061/                                                            https://www.matchbook.com/events/soccer/brazil/brazil-serie-a/31313435410600061/         26.393400
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense     matchbook       Matchbook       3.05       2.86       2.98                                                            https://www.matchbook.com/events/soccer/brazil/brazil-serie-b/31314566281400061/                                                            https://www.matchbook.com/events/soccer/brazil/brazil-serie-b/31314566281400061/                                                            https://www.matchbook.com/events/soccer/brazil/brazil-serie-b/31314566281400061/         25.994540
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense betfair_ex_eu         Betfair       3.00       2.84       2.98                                                                           https://www.betfair.com/exchange/plus/football/market/1.248388168                                                                           https://www.betfair.com/exchange/plus/football/market/1.248388168                                                                           https://www.betfair.com/exchange/plus/football/market/1.248388168         25.389600
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza      pinnacle        Pinnacle       2.57       3.20       3.01                                                        https://www.pinnacle.com/en/soccer/brazil-serie-a/fortaleza-vs-juventude/1616434361/                                                        https://www.pinnacle.com/en/soccer/brazil-serie-a/fortaleza-vs-juventude/1616434361/                                                        https://www.pinnacle.com/en/soccer/brazil-serie-a/fortaleza-vs-juventude/1616434361/         24.754240
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos      pinnacle        Pinnacle       2.57       3.00       3.21                                                               https://www.pinnacle.com/en/soccer/brazil-serie-a/santos-vs-ceara/1616455274/                                                               https://www.pinnacle.com/en/soccer/brazil-serie-a/santos-vs-ceara/1616455274/                                                               https://www.pinnacle.com/en/soccer/brazil-serie-a/santos-vs-ceara/1616455274/         24.749100
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos       coolbet         Coolbet       2.46       3.00       3.33                                                                                             https://www.coolbet.com/en/sports/match/4456702                                                                                             https://www.coolbet.com/en/sports/match/4456702                                                                                             https://www.coolbet.com/en/sports/match/4456702         24.575400
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos       onexbet           1xBet       2.44       3.15       3.17                                      https://1xbet.com/en/line/football/1268397-brazil-campeonato-brasileiro-serie-a/280925414-ceara-santos                                      https://1xbet.com/en/line/football/1268397-brazil-campeonato-brasileiro-serie-a/280925414-ceara-santos                                      https://1xbet.com/en/line/football/1268397-brazil-campeonato-brasileiro-serie-a/280925414-ceara-santos         24.364620
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza       coolbet         Coolbet       2.55       3.15       3.03                                                                                             https://www.coolbet.com/en/sports/match/4456658                                                                                             https://www.coolbet.com/en/sports/match/4456658                                                                                             https://www.coolbet.com/en/sports/match/4456658         24.338475
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense      pinnacle        Pinnacle       3.04       2.77       2.87                                   https://www.pinnacle.com/en/soccer/brazil-serie-b/athletico-paranaense-vs-atletico-goianiense/1616540568/                                   https://www.pinnacle.com/en/soccer/brazil-serie-b/athletico-paranaense-vs-atletico-goianiense/1616540568/                                   https://www.pinnacle.com/en/soccer/brazil-serie-b/athletico-paranaense-vs-atletico-goianiense/1616540568/         24.167696
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos   betonlineag    BetOnline.ag       2.45       2.98       3.27                                                                         https://sports.betonline.ag/sportsbook/soccer/brazil/game/490835603                                                                         https://sports.betonline.ag/sportsbook/soccer/brazil/game/490835603                                                                         https://sports.betonline.ag/sportsbook/soccer/brazil/game/490835603         23.874270
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos  betanysports     BetAnything       2.45       2.98       3.27                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         23.874270
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos        gtbets          GTbets       2.45       3.01       3.20                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         23.598400
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza        gtbets          GTbets       2.57       3.18       2.82                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         23.046732
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos     everygame       Everygame       2.50       2.95       3.10                                                      https://sports.everygame.eu/en/Bets/Soccer/Brazilian-Serie-A/Ceara-v-Santos-FC/2721536                                                      https://sports.everygame.eu/en/Bets/Soccer/Brazilian-Serie-A/Ceara-v-Santos-FC/2721536                                                      https://sports.everygame.eu/en/Bets/Soccer/Brazilian-Serie-A/Ceara-v-Santos-FC/2721536         22.862500
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza     unibet_it     Unibet (IT)       2.45       3.15       2.95                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         22.766625
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza     unibet_nl     Unibet (NL)       2.45       3.15       2.95                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         22.766625
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza     unibet_se     Unibet (SE)       2.45       3.15       2.95                                                                                       https://www.unibet.se/betting/sports/event/1022853453                                                                                       https://www.unibet.se/betting/sports/event/1022853453                                                                                       https://www.unibet.se/betting/sports/event/1022853453         22.766625
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense     unibet_it     Unibet (IT)       2.95       2.80       2.70                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         22.302000
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense     unibet_nl     Unibet (NL)       2.95       2.80       2.70                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         22.302000
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense     unibet_se     Unibet (SE)       2.95       2.80       2.70                                                                                       https://www.unibet.se/betting/sports/event/1022949546                                                                                       https://www.unibet.se/betting/sports/event/1022949546                                                                                       https://www.unibet.se/betting/sports/event/1022949546         22.302000
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza   marathonbet    Marathon Bet       2.52       3.18       2.78                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         22.277808
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza   betonlineag    BetOnline.ag       2.52       3.15       2.80                                                                         https://sports.betonline.ag/sportsbook/soccer/brazil/game/490835611                                                                         https://sports.betonline.ag/sportsbook/soccer/brazil/game/490835611                                                                         https://sports.betonline.ag/sportsbook/soccer/brazil/game/490835611         22.226400
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza  betanysports     BetAnything       2.52       3.15       2.80                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         22.226400
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza     everygame       Everygame       2.50       3.10       2.85                                            https://sports.everygame.eu/en/Bets/Soccer/Brazilian-Serie-A/Juventude-RS-v-Fortaleza-CE/2721533                                            https://sports.everygame.eu/en/Bets/Soccer/Brazilian-Serie-A/Juventude-RS-v-Fortaleza-CE/2721533                                            https://sports.everygame.eu/en/Bets/Soccer/Brazilian-Serie-A/Juventude-RS-v-Fortaleza-CE/2721533         22.087500
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos       betsson         Betsson       2.52       2.85       3.05   https://www.betsson.com/en/sportsbook/football/brazil/brazil---serie-a?tab=liveAndUpcoming&eventId=f-SMQC4lljo0yExBzni7dOPw&eti=0&fs=true   https://www.betsson.com/en/sportsbook/football/brazil/brazil---serie-a?tab=liveAndUpcoming&eventId=f-SMQC4lljo0yExBzni7dOPw&eti=0&fs=true   https://www.betsson.com/en/sportsbook/football/brazil/brazil---serie-a?tab=liveAndUpcoming&eventId=f-SMQC4lljo0yExBzni7dOPw&eti=0&fs=true         21.905100
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza     nordicbet      Nordic Bet       2.52       3.05       2.85                                                  https://www.nordicbet.com/en/sportsbook/football/brazil/brazil-serie-a/juventude-fortaleza                                                  https://www.nordicbet.com/en/sportsbook/football/brazil/brazil-serie-a/juventude-fortaleza                                                  https://www.nordicbet.com/en/sportsbook/football/brazil/brazil-serie-a/juventude-fortaleza         21.905100
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense       coolbet         Coolbet       2.95       2.75       2.70                                                                                             https://www.coolbet.com/en/sports/match/4457115                                                                                             https://www.coolbet.com/en/sports/match/4457115                                                                                             https://www.coolbet.com/en/sports/match/4457115         21.903750
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza   leovegas_se   LeoVegas (SE)       2.43       3.10       2.90                                                                                     https://www.leovegas.com/sv-se/betting#event/1022853453                                                                                     https://www.leovegas.com/sv-se/betting#event/1022853453                                                                                     https://www.leovegas.com/sv-se/betting#event/1022853453         21.845700
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza       betsson         Betsson       2.65       3.05       2.70   https://www.betsson.com/en/sportsbook/football/brazil/brazil---serie-a?tab=liveAndUpcoming&eventId=f-9BIpp2hJIU21szBOEVMVaw&eti=0&fs=true   https://www.betsson.com/en/sportsbook/football/brazil/brazil---serie-a?tab=liveAndUpcoming&eventId=f-9BIpp2hJIU21szBOEVMVaw&eti=0&fs=true   https://www.betsson.com/en/sportsbook/football/brazil/brazil---serie-a?tab=liveAndUpcoming&eventId=f-9BIpp2hJIU21szBOEVMVaw&eti=0&fs=true         21.822750
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense       onexbet           1xBet       2.84       2.86       2.65 https://1xbet.com/en/line/football/57265-brazil-campeonato-brasileiro-serie-b/280930939-atletico-clube-goianiense-clube-atletico-paranaense https://1xbet.com/en/line/football/57265-brazil-campeonato-brasileiro-serie-b/280930939-atletico-clube-goianiense-clube-atletico-paranaense https://1xbet.com/en/line/football/57265-brazil-campeonato-brasileiro-serie-b/280930939-atletico-clube-goianiense-clube-atletico-paranaense         21.524360
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense   betonlineag    BetOnline.ag       2.83       2.76       2.74                                                                         https://sports.betonline.ag/sportsbook/soccer/brazil/game/490836940                                                                         https://sports.betonline.ag/sportsbook/soccer/brazil/game/490836940                                                                         https://sports.betonline.ag/sportsbook/soccer/brazil/game/490836940         21.401592
# 8b115074d1d85e8df5185b06851c3e02 soccer_brazil_campeonato 2025-10-05T23:30:00Z               Ceará              Santos     tipico_de          Tipico       2.45       2.80       3.10                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         21.266000
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza     tipico_de          Tipico       2.50       2.95       2.85                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         21.018750
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza   williamhill    William Hill       2.50       3.00       2.80                                               https://sports.williamhill.com/betting/en-gb/football/OB_EV37212679/juventude-rs-vs-fortaleza                                               https://sports.williamhill.com/betting/en-gb/football/OB_EV37212679/juventude-rs-vs-fortaleza                                               https://sports.williamhill.com/betting/en-gb/football/OB_EV37212679/juventude-rs-vs-fortaleza         21.000000
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense   williamhill    William Hill       2.90       2.75       2.62                                     https://sports.williamhill.com/betting/en-gb/football/OB_EV37199980/atletico-go-vs-athletico-paranaense                                     https://sports.williamhill.com/betting/en-gb/football/OB_EV37199980/atletico-go-vs-athletico-paranaense                                     https://sports.williamhill.com/betting/en-gb/football/OB_EV37199980/atletico-go-vs-athletico-paranaense         20.894500
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense   leovegas_se   LeoVegas (SE)       2.88       2.75       2.63                                                                                     https://www.leovegas.com/sv-se/betting#event/1022949546                                                                                     https://www.leovegas.com/sv-se/betting#event/1022949546                                                                                     https://www.leovegas.com/sv-se/betting#event/1022949546         20.829600
# a4b8d73f917efec41321519fbae8d952 soccer_brazil_campeonato 2025-10-05T21:30:00Z           Juventude           Fortaleza    winamax_de    Winamax (DE)       2.50       3.05       2.70                                                                                     https://www.winamax.de/en/sports-betting/match/58053011                                                                                     https://www.winamax.de/en/sports-betting/match/58053011                                                                                     https://www.winamax.de/en/sports-betting/match/58053011         20.587500
# 8dc221973be465fc93fa15395a1f2946    soccer_brazil_serie_b 2025-10-05T23:30:00Z Atletico Goianiense Atletico Paranaense     tipico_de          Tipico       2.95       2.65       2.55                                                                                                                                        None                                                                                                                                        None                                                                                                                                        None         19.934625
#
# Les résultats ont été enregistrés dans le fichier 'data-paris-sportifs.csv'.

# %%
data_paris_sportifs = pd.read_csv("./data/data-paris-sportifs.csv")
data_paris_sportifs
# Out:
#                             event_id                 sport_key  \
# 0   a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 1   a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 2   8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 3   8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 4   8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 5   8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 6   a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 7   8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 8   8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 9   8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 10  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 11  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 12  8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 13  8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 14  8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 15  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 16  8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 17  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 18  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 19  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 20  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 21  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 22  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 23  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 24  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 25  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 26  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 27  8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 28  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 29  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 30  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 31  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 32  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 33  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 34  8b115074d1d85e8df5185b06851c3e02  soccer_brazil_campeonato
# 35  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 36  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 37  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 38  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
# 39  a4b8d73f917efec41321519fbae8d952  soccer_brazil_campeonato
# 40  8dc221973be465fc93fa15395a1f2946     soccer_brazil_serie_b
#
#            commence_time            home_team            away_team  \
# 0   2025-10-05T21:30:00Z            Juventude            Fortaleza
# 1   2025-10-05T21:30:00Z            Juventude            Fortaleza
# 2   2025-10-05T23:30:00Z                Ceará               Santos
# 3   2025-10-05T23:30:00Z                Ceará               Santos
# 4   2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 5   2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 6   2025-10-05T21:30:00Z            Juventude            Fortaleza
# 7   2025-10-05T23:30:00Z                Ceará               Santos
# 8   2025-10-05T23:30:00Z                Ceará               Santos
# 9   2025-10-05T23:30:00Z                Ceará               Santos
# 10  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 11  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 12  2025-10-05T23:30:00Z                Ceará               Santos
# 13  2025-10-05T23:30:00Z                Ceará               Santos
# 14  2025-10-05T23:30:00Z                Ceará               Santos
# 15  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 16  2025-10-05T23:30:00Z                Ceará               Santos
# 17  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 18  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 19  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 20  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 21  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 22  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 23  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 24  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 25  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 26  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 27  2025-10-05T23:30:00Z                Ceará               Santos
# 28  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 29  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 30  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 31  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 32  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 33  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 34  2025-10-05T23:30:00Z                Ceará               Santos
# 35  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 36  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 37  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 38  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
# 39  2025-10-05T21:30:00Z            Juventude            Fortaleza
# 40  2025-10-05T23:30:00Z  Atletico Goianiense  Atletico Paranaense
#
#         bookmaker bookmaker_title  home_odds  draw_odds  away_odds  \
# 0       matchbook       Matchbook       2.90       3.25       2.84
# 1   betfair_ex_eu         Betfair       2.90       3.25       2.82
# 2   betfair_ex_eu         Betfair       2.58       3.10       3.30
# 3       matchbook       Matchbook       2.58       3.10       3.30
# 4       matchbook       Matchbook       3.05       2.86       2.98
# 5   betfair_ex_eu         Betfair       3.00       2.84       2.98
# 6        pinnacle        Pinnacle       2.57       3.20       3.01
# 7        pinnacle        Pinnacle       2.57       3.00       3.21
# 8         coolbet         Coolbet       2.46       3.00       3.33
# 9         onexbet           1xBet       2.44       3.15       3.17
# 10        coolbet         Coolbet       2.55       3.15       3.03
# 11       pinnacle        Pinnacle       3.04       2.77       2.87
# 12    betonlineag    BetOnline.ag       2.45       2.98       3.27
# 13   betanysports     BetAnything       2.45       2.98       3.27
# 14         gtbets          GTbets       2.45       3.01       3.20
# 15         gtbets          GTbets       2.57       3.18       2.82
# 16      everygame       Everygame       2.50       2.95       3.10
# 17      unibet_it     Unibet (IT)       2.45       3.15       2.95
# 18      unibet_nl     Unibet (NL)       2.45       3.15       2.95
# 19      unibet_se     Unibet (SE)       2.45       3.15       2.95
# 20      unibet_it     Unibet (IT)       2.95       2.80       2.70
# 21      unibet_nl     Unibet (NL)       2.95       2.80       2.70
# 22      unibet_se     Unibet (SE)       2.95       2.80       2.70
# 23    marathonbet    Marathon Bet       2.52       3.18       2.78
# 24    betonlineag    BetOnline.ag       2.52       3.15       2.80
# 25   betanysports     BetAnything       2.52       3.15       2.80
# 26      everygame       Everygame       2.50       3.10       2.85
# 27        betsson         Betsson       2.52       2.85       3.05
# 28      nordicbet      Nordic Bet       2.52       3.05       2.85
# 29        coolbet         Coolbet       2.95       2.75       2.70
# 30    leovegas_se   LeoVegas (SE)       2.43       3.10       2.90
# 31        betsson         Betsson       2.65       3.05       2.70
# 32        onexbet           1xBet       2.84       2.86       2.65
# 33    betonlineag    BetOnline.ag       2.83       2.76       2.74
# 34      tipico_de          Tipico       2.45       2.80       3.10
# 35      tipico_de          Tipico       2.50       2.95       2.85
# 36    williamhill    William Hill       2.50       3.00       2.80
# 37    williamhill    William Hill       2.90       2.75       2.62
# 38    leovegas_se   LeoVegas (SE)       2.88       2.75       2.63
# 39     winamax_de    Winamax (DE)       2.50       3.05       2.70
# 40      tipico_de          Tipico       2.95       2.65       2.55
#
#                                             home_link  \
# 0   https://www.matchbook.com/events/soccer/brazil...
# 1   https://www.betfair.com/exchange/plus/football...
# 2   https://www.betfair.com/exchange/plus/football...
# 3   https://www.matchbook.com/events/soccer/brazil...
# 4   https://www.matchbook.com/events/soccer/brazil...
# 5   https://www.betfair.com/exchange/plus/football...
# 6   https://www.pinnacle.com/en/soccer/brazil-seri...
# 7   https://www.pinnacle.com/en/soccer/brazil-seri...
# 8     https://www.coolbet.com/en/sports/match/4456702
# 9   https://1xbet.com/en/line/football/1268397-bra...
# 10    https://www.coolbet.com/en/sports/match/4456658
# 11  https://www.pinnacle.com/en/soccer/brazil-seri...
# 12  https://sports.betonline.ag/sportsbook/soccer/...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  https://sports.everygame.eu/en/Bets/Soccer/Bra...
# 17                                                NaN
# 18                                                NaN
# 19  https://www.unibet.se/betting/sports/event/102...
# 20                                                NaN
# 21                                                NaN
# 22  https://www.unibet.se/betting/sports/event/102...
# 23                                                NaN
# 24  https://sports.betonline.ag/sportsbook/soccer/...
# 25                                                NaN
# 26  https://sports.everygame.eu/en/Bets/Soccer/Bra...
# 27  https://www.betsson.com/en/sportsbook/football...
# 28  https://www.nordicbet.com/en/sportsbook/footba...
# 29    https://www.coolbet.com/en/sports/match/4457115
# 30  https://www.leovegas.com/sv-se/betting#event/1...
# 31  https://www.betsson.com/en/sportsbook/football...
# 32  https://1xbet.com/en/line/football/57265-brazi...
# 33  https://sports.betonline.ag/sportsbook/soccer/...
# 34                                                NaN
# 35                                                NaN
# 36  https://sports.williamhill.com/betting/en-gb/f...
# 37  https://sports.williamhill.com/betting/en-gb/f...
# 38  https://www.leovegas.com/sv-se/betting#event/1...
# 39  https://www.winamax.de/en/sports-betting/match...
# 40                                                NaN
#
#                                             draw_link  \
# 0   https://www.matchbook.com/events/soccer/brazil...
# 1   https://www.betfair.com/exchange/plus/football...
# 2   https://www.betfair.com/exchange/plus/football...
# 3   https://www.matchbook.com/events/soccer/brazil...
# 4   https://www.matchbook.com/events/soccer/brazil...
# 5   https://www.betfair.com/exchange/plus/football...
# 6   https://www.pinnacle.com/en/soccer/brazil-seri...
# 7   https://www.pinnacle.com/en/soccer/brazil-seri...
# 8     https://www.coolbet.com/en/sports/match/4456702
# 9   https://1xbet.com/en/line/football/1268397-bra...
# 10    https://www.coolbet.com/en/sports/match/4456658
# 11  https://www.pinnacle.com/en/soccer/brazil-seri...
# 12  https://sports.betonline.ag/sportsbook/soccer/...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  https://sports.everygame.eu/en/Bets/Soccer/Bra...
# 17                                                NaN
# 18                                                NaN
# 19  https://www.unibet.se/betting/sports/event/102...
# 20                                                NaN
# 21                                                NaN
# 22  https://www.unibet.se/betting/sports/event/102...
# 23                                                NaN
# 24  https://sports.betonline.ag/sportsbook/soccer/...
# 25                                                NaN
# 26  https://sports.everygame.eu/en/Bets/Soccer/Bra...
# 27  https://www.betsson.com/en/sportsbook/football...
# 28  https://www.nordicbet.com/en/sportsbook/footba...
# 29    https://www.coolbet.com/en/sports/match/4457115
# 30  https://www.leovegas.com/sv-se/betting#event/1...
# 31  https://www.betsson.com/en/sportsbook/football...
# 32  https://1xbet.com/en/line/football/57265-brazi...
# 33  https://sports.betonline.ag/sportsbook/soccer/...
# 34                                                NaN
# 35                                                NaN
# 36  https://sports.williamhill.com/betting/en-gb/f...
# 37  https://sports.williamhill.com/betting/en-gb/f...
# 38  https://www.leovegas.com/sv-se/betting#event/1...
# 39  https://www.winamax.de/en/sports-betting/match...
# 40                                                NaN
#
#                                             away_link  combined_product
# 0   https://www.matchbook.com/events/soccer/brazil...         26.767000
# 1   https://www.betfair.com/exchange/plus/football...         26.578500
# 2   https://www.betfair.com/exchange/plus/football...         26.393400
# 3   https://www.matchbook.com/events/soccer/brazil...         26.393400
# 4   https://www.matchbook.com/events/soccer/brazil...         25.994540
# 5   https://www.betfair.com/exchange/plus/football...         25.389600
# 6   https://www.pinnacle.com/en/soccer/brazil-seri...         24.754240
# 7   https://www.pinnacle.com/en/soccer/brazil-seri...         24.749100
# 8     https://www.coolbet.com/en/sports/match/4456702         24.575400
# 9   https://1xbet.com/en/line/football/1268397-bra...         24.364620
# 10    https://www.coolbet.com/en/sports/match/4456658         24.338475
# 11  https://www.pinnacle.com/en/soccer/brazil-seri...         24.167696
# 12  https://sports.betonline.ag/sportsbook/soccer/...         23.874270
# 13                                                NaN         23.874270
# 14                                                NaN         23.598400
# 15                                                NaN         23.046732
# 16  https://sports.everygame.eu/en/Bets/Soccer/Bra...         22.862500
# 17                                                NaN         22.766625
# 18                                                NaN         22.766625
# 19  https://www.unibet.se/betting/sports/event/102...         22.766625
# 20                                                NaN         22.302000
# 21                                                NaN         22.302000
# 22  https://www.unibet.se/betting/sports/event/102...         22.302000
# 23                                                NaN         22.277808
# 24  https://sports.betonline.ag/sportsbook/soccer/...         22.226400
# 25                                                NaN         22.226400
# 26  https://sports.everygame.eu/en/Bets/Soccer/Bra...         22.087500
# 27  https://www.betsson.com/en/sportsbook/football...         21.905100
# 28  https://www.nordicbet.com/en/sportsbook/footba...         21.905100
# 29    https://www.coolbet.com/en/sports/match/4457115         21.903750
# 30  https://www.leovegas.com/sv-se/betting#event/1...         21.845700
# 31  https://www.betsson.com/en/sportsbook/football...         21.822750
# 32  https://1xbet.com/en/line/football/57265-brazi...         21.524360
# 33  https://sports.betonline.ag/sportsbook/soccer/...         21.401592
# 34                                                NaN         21.266000
# 35                                                NaN         21.018750
# 36  https://sports.williamhill.com/betting/en-gb/f...         21.000000
# 37  https://sports.williamhill.com/betting/en-gb/f...         20.894500
# 38  https://www.leovegas.com/sv-se/betting#event/1...         20.829600
# 39  https://www.winamax.de/en/sports-betting/match...         20.587500
# 40                                                NaN         19.934625

# %%
# Filtrer le dataframe pour afficher uniquement les bookmakers français (contenant '(FR)' dans 'bookmaker_title')
df_paris_sportifs_fr = data_paris_sportifs[data_paris_sportifs['bookmaker_title'].str.contains(r'\(FR\)', na=False)]
df_paris_sportifs_fr
# Out:
# Empty DataFrame
# Columns: [event_id, sport_key, commence_time, home_team, away_team, bookmaker, bookmaker_title, home_odds, draw_odds, away_odds, home_link, draw_link, away_link, combined_product]
# Index: []
