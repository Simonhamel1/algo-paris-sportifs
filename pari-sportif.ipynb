# %%
#quotas restant api
import requests
import time
import os
from dotenv import load_dotenv
import pandas as pd

load_dotenv()

API_KEY = ="" # Assumes your API key is stored in an environment variable

def get_remaining_quotas(api_key):
    url = "https://api.the-odds-api.com/v4/sports"
    params = {"apiKey": api_key}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        # Quota info is in response headers
        quota_used = response.headers.get("x-requests-used")
        quota_remaining = response.headers.get("x-requests-remaining")
        return quota_used, quota_remaining
    else:
        raise Exception(f"API request failed: {response.status_code} {response.text}")

if API_KEY:
    used, remaining = get_remaining_quotas(API_KEY)
    print(f"API quota used: {used}, remaining: {remaining}")
    with open("./data/quotas.txt", "a") as f:
        f.write(f"API quota used: {used}, remaining: {remaining} at {time.ctime()}\n")
else:
    print("ODDS_API_KEY environment variable not set.")
# Out:
# ODDS_API_KEY environment variable not set.

# %%
"""
Script pour récupérer et filtrer les cotes avec The Odds API (v4).

Ce script montre comment obtenir les cotes 1N2 (domicile/nul/extérieur)
pour un ou plusieurs sports, identifier les événements où les trois issues
ont des cotes proches d'une valeur cible, et assembler les résultats dans un DataFrame pandas.

Principales fonctionnalités :

    • Utilise la clé API fournie pour authentifier les requêtes vers The Odds API.
    • Demande les cotes décimales pour le marché h2h (1N2) et inclut les liens profonds
        (`includeLinks=true`) et les identifiants de source (`includeSids=true`).
    • Extrait le meilleur prix disponible pour chaque issue par bookmaker et
        sélectionne le lien le plus profond dans la hiérarchie issue → marché →
        bookmaker → événement, comme recommandé par la documentation de The Odds API.
    • Filtre les bookmakers dont les cotes pour les trois issues sont toutes dans
        une tolérance configurable autour d'une valeur cible (par défaut 3.0 ± 0.6) et trie
        les résultats par le produit des trois cotes.

Utilisation :

    Définissez la variable `API_KEY` ci-dessous avec votre clé Odds API valide. Puis lancez :

            python3 odds_filter_script.py

    Par défaut, le script interroge la Premier League anglaise (clé de sport
    'soccer_epl'). Vous pouvez changer `SPORT_KEYS` pour une liste d'autres sports
    (ex : ['americanfootball_nfl', 'basketball_nba']) ou utiliser l'endpoint
    '/v4/sports' pour découvrir les clés disponibles.

Dépendances :

    pip install requests pandas

Note :
    Ce script est prévu pour une exécution locale. Les appels réseau sont désactivés
    dans cet environnement de chat, donc il ne fonctionnera pas ici.
    Enregistrez-le sur votre machine et exécutez-le avec un accès internet.
"""

import os
from typing import Dict, List, Optional, Any, Tuple

import requests
import pandas as pd

# ============================ Configuration ============================

# Remplacez ceci par votre propre clé API. Ne partagez jamais de clé réelle publiquement.
API_KEY: str = "5bb24e9151caf14c896925a570220a78"

# Liste des clés de sport à interroger. 'soccer_epl' pour la Premier League,
# 'upcoming' pour un mélange de sports, ou appelez /v4/sports pour en découvrir d'autres.
SPORT_KEYS: List[str] = ["upcoming"]

# Cote cible et tolérance. Le script sélectionne les événements où les cotes domicile,
# nul et extérieur sont toutes dans [TARGET - TOL, TARGET + TOL].
TARGET: float = 3.0
TOL: float = 0.6

# Codes régionaux pour les bookmakers. 'eu' retourne les bookmakers européens.
REGION: str = "eu"

# =========================== Fonctions Utilitaires ===========================

def fetch_odds(
        api_key: str,
        sport_key: str,
        region: str = REGION,
        markets: str = "h2h",
        odds_format: str = "decimal",
        include_links: bool = True,
        include_sids: bool = True,
) -> List[Dict[str, Any]]:
        """Récupère les cotes pour un sport donné via The Odds API.

        Args:
                api_key: Votre clé Odds API.
                sport_key: Identifiant du sport (ex : 'soccer_epl').
                region: Code(s) régionaux comme 'eu', 'us', 'uk'. Séparez par des virgules pour plusieurs.
                markets: Marché ; 'h2h' retourne les cotes 1N2 pour le foot.
                odds_format: Format des cotes ('decimal' ou 'american').
                include_links: Inclure les liens profonds (ajoute includeLinks=true).
                include_sids: Inclure les IDs de source (ajoute includeSids=true).

        Returns:
                Une liste de dictionnaires d'événements retournés par l'API.
        """
        url = f"https://api.the-odds-api.com/v4/sports/{sport_key}/odds/"
        params: Dict[str, Any] = {
                "apiKey": api_key,
                "regions": region,
                "markets": markets,
                "oddsFormat": odds_format,
        }
        if include_links:
                params["includeLinks"] = "true"
        if include_sids:
                params["includeSids"] = "true"
        response = requests.get(url, params=params, timeout=30)
        if response.status_code == 404:
                # Sport non disponible ou hors saison
                return []
        response.raise_for_status()
        return response.json()

def _deep_link(event: Dict, bookmaker: Dict, market: Dict, outcome: Dict) -> Optional[str]:
        """Retourne le lien le plus profond selon la hiérarchie de l'API.

        Ordre recommandé : outcome.link → market.link → bookmaker.link → event.link

        Args:
                event: Dictionnaire d'événement pouvant contenir un 'link'.
                bookmaker: Dictionnaire bookmaker pouvant contenir un 'link'.
                market: Dictionnaire marché pouvant contenir un 'link'.
                outcome: Dictionnaire issue pouvant contenir un 'link'.

        Returns:
                Le premier lien non vide trouvé ou None.
        """
        return (
                outcome.get("link")
                or market.get("link")
                or bookmaker.get("link")
                or event.get("link")
        )

def extract_bookmaker_odds(event: Dict) -> List[Dict[str, Any]]:
        """Extrait les meilleures cotes domicile/nul/extérieur et liens par bookmaker pour un événement.

        Args:
                event: Dictionnaire d'événement de l'API, contenant bookmakers et marchés.

        Returns:
                Une liste où chaque élément correspond à un bookmaker proposant les trois issues.
                Chaque élément contient les cotes et liens profonds.
        """
        results: List[Dict[str, Any]] = []
        home_team = event.get("home_team")
        away_team = event.get("away_team")
        for bookmaker in event.get("bookmakers", []):
                book_key = bookmaker.get("key")
                book_title = bookmaker.get("title", book_key)
                for market in bookmaker.get("markets", []):
                        if market.get("key") != "h2h":
                                continue
                        odds_map: Dict[str, float] = {}
                        link_map: Dict[str, Optional[str]] = {}
                        for outcome in market.get("outcomes", []):
                                name = outcome.get("name", "")
                                price = outcome.get("price")
                                if name.lower() in {"draw", "tie", "egalité"}:
                                        key = "draw"
                                elif name == home_team:
                                        key = "home"
                                elif name == away_team:
                                        key = "away"
                                else:
                                        continue
                                try:
                                        price_val = float(price)
                                except (TypeError, ValueError):
                                        continue
                                odds_map[key] = price_val
                                link_map[key] = _deep_link(event, bookmaker, market, outcome)
                        if len(odds_map) == 3:
                                results.append(
                                        {
                                                "event_id": event.get("id"),
                                                "sport_key": event.get("sport_key"),
                                                "commence_time": event.get("commence_time"),
                                                "home_team": home_team,
                                                "away_team": away_team,
                                                "bookmaker": book_key,
                                                "bookmaker_title": book_title,
                                                "home_odds": odds_map["home"],
                                                "draw_odds": odds_map["draw"],
                                                "away_odds": odds_map["away"],
                                                "home_link": link_map["home"],
                                                "draw_link": link_map["draw"],
                                                "away_link": link_map["away"],
                                        }
                                )
        return results

def find_events_with_target_odds(
        api_key: str,
        sport_keys: List[str],
        target: float = TARGET,
        tol: float = TOL,
        region: str = REGION,
) -> pd.DataFrame:
        """Récupère et filtre les offres bookmakers proches d'une cote cible.

        Args:
                api_key: Clé Odds API.
                sport_keys: Liste des identifiants de sport à interroger.
                target: Cote souhaitée autour de laquelle les trois issues doivent se situer.
                tol: Tolérance autour de la cote cible.
                region: Code(s) régionaux pour les bookmakers (ex : 'eu').

        Returns:
                Un DataFrame pandas avec une ligne par (événement, bookmaker) répondant aux critères.
                Colonnes : équipes, cotes, liens profonds et produit des cotes pour le tri.
        """
        records: List[Dict[str, Any]] = []
        for sport_key in sport_keys:
                try:
                        events = fetch_odds(api_key, sport_key, region=region)
                except Exception as exc:
                        print(f"Erreur lors de la récupération des cotes pour {sport_key} : {exc}")
                        continue
                for event in events:
                        for rec in extract_bookmaker_odds(event):
                                if (
                                        abs(rec["home_odds"] - target) <= tol
                                        and abs(rec["draw_odds"] - target) <= tol
                                        and abs(rec["away_odds"] - target) <= tol
                                ):
                                        rec["combined_product"] = (
                                                rec["home_odds"] * rec["draw_odds"] * rec["away_odds"]
                                        )
                                        records.append(rec)
        df = pd.DataFrame(records)
        if not df.empty:
                df = df.sort_values("combined_product", ascending=False).reset_index(drop=True)
        return df

def main() -> None:
        """Point d'entrée du script. Récupère les cotes, filtre et affiche le résultat."""
        if not API_KEY:
                print("Aucune clé API n'est configurée. Veuillez définir API_KEY dans le script.")
                return
        if not SPORT_KEYS:
                print("Aucune clé de sport fournie. Spécifiez au moins un sport.")
                return
        df = find_events_with_target_odds(API_KEY, SPORT_KEYS, TARGET, TOL, REGION)
        if df.empty:
                print("Aucun événement correspondant aux critères n'a été trouvé.")
        else:
                with pd.option_context('display.max_columns', None):
                        print(df.to_string(index=False))
                df.to_csv("./data/data-paris-sportifs.csv", index=False)
                print("\nLes résultats ont été enregistrés dans le fichier 'data-paris-sportifs.csv'.")

if __name__ == "__main__":
        main()
# Out:
#                         event_id                 sport_key        commence_time        home_team      away_team       bookmaker    bookmaker_title  home_odds  draw_odds  away_odds                                                                                                                                        home_link                                                                                                                                        draw_link                                                                                                                                        away_link  combined_product
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma   betfair_ex_eu            Betfair       3.30       3.20       2.58                                                                                https://www.betfair.com/exchange/plus/football/market/1.248073501                                                                                https://www.betfair.com/exchange/plus/football/market/1.248073501                                                                                https://www.betfair.com/exchange/plus/football/market/1.248073501         27.244800
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma       matchbook          Matchbook       3.30       3.20       2.56                                                                   https://www.matchbook.com/events/soccer/italy/italy-serie-a/31252889393400061/                                                                   https://www.matchbook.com/events/soccer/italy/italy-serie-a/31252889393400061/                                                                   https://www.matchbook.com/events/soccer/italy/italy-serie-a/31252889393400061/         27.033600
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace   betfair_ex_eu            Betfair       2.80       3.20       2.98                                                                                https://www.betfair.com/exchange/plus/football/market/1.248023163                                                                                https://www.betfair.com/exchange/plus/football/market/1.248023163                                                                                https://www.betfair.com/exchange/plus/football/market/1.248023163         26.700800
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace       matchbook          Matchbook       2.80       3.20       2.98                                                        https://www.matchbook.com/events/soccer/england/english-premier-league/31244056039200061/                                                        https://www.matchbook.com/events/soccer/england/english-premier-league/31244056039200061/                                                        https://www.matchbook.com/events/soccer/england/english-premier-league/31244056039200061/         26.700800
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace         coolbet            Coolbet       2.77       3.18       2.90                                                                                                  https://www.coolbet.com/en/sports/match/4420209                                                                                                  https://www.coolbet.com/en/sports/match/4420209                                                                                                  https://www.coolbet.com/en/sports/match/4420209         25.544940
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma        pinnacle           Pinnacle       3.25       3.19       2.46                                                                  https://www.pinnacle.com/en/soccer/italy-serie-a/roma-vs-fiorentina/1615845210/                                                                  https://www.pinnacle.com/en/soccer/italy-serie-a/roma-vs-fiorentina/1615845210/                                                                  https://www.pinnacle.com/en/soccer/italy-serie-a/roma-vs-fiorentina/1615845210/         25.504050
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace       unibet_se        Unibet (SE)       2.80       3.25       2.80                                                                                            https://www.unibet.se/betting/sports/event/1024043905                                                                                            https://www.unibet.se/betting/sports/event/1024043905                                                                                            https://www.unibet.se/betting/sports/event/1024043905         25.480000
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace       unibet_nl        Unibet (NL)       2.80       3.25       2.80                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         25.480000
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz   betfair_ex_eu            Betfair       3.15       2.82       2.84                                                                                https://www.betfair.com/exchange/plus/football/market/1.248358315                                                                                https://www.betfair.com/exchange/plus/football/market/1.248358315                                                                                https://www.betfair.com/exchange/plus/football/market/1.248358315         25.227720
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma         coolbet            Coolbet       3.20       3.15       2.50                                                                                                  https://www.coolbet.com/en/sports/match/4424966                                                                                                  https://www.coolbet.com/en/sports/match/4424966                                                                                                  https://www.coolbet.com/en/sports/match/4424966         25.200000
# c625878da7e09846e8c9e30d83f65f36      soccer_italy_serie_b 2025-10-05T13:00:00Z        Carrarese    Juve Stabia        pinnacle           Pinnacle       2.46       2.96       3.45                                                            https://www.pinnacle.com/en/soccer/italy-serie-b/juve-stabia-vs-carrarese/1616418775/                                                            https://www.pinnacle.com/en/soccer/italy-serie-b/juve-stabia-vs-carrarese/1616418775/                                                            https://www.pinnacle.com/en/soccer/italy-serie-b/juve-stabia-vs-carrarese/1616418775/         25.121520
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma         onexbet              1xBet       3.06       3.27       2.50                                                                https://1xbet.com/en/line/football/110163-italy-serie-a/279860477-fiorentina-roma                                                                https://1xbet.com/en/line/football/110163-italy-serie-a/279860477-fiorentina-roma                                                                https://1xbet.com/en/line/football/110163-italy-serie-a/279860477-fiorentina-roma         25.015500
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma       unibet_se        Unibet (SE)       3.15       3.20       2.48                                                                                            https://www.unibet.se/betting/sports/event/1023931820                                                                                            https://www.unibet.se/betting/sports/event/1023931820                                                                                            https://www.unibet.se/betting/sports/event/1023931820         24.998400
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma       unibet_nl        Unibet (NL)       3.15       3.20       2.48                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         24.998400
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace        pinnacle           Pinnacle       2.72       3.14       2.92                                                  https://www.pinnacle.com/en/soccer/england-premier-league/crystal-palace-vs-everton/1615845209/                                                  https://www.pinnacle.com/en/soccer/england-premier-league/crystal-palace-vs-everton/1615845209/                                                  https://www.pinnacle.com/en/soccer/england-premier-league/crystal-palace-vs-everton/1615845209/         24.939136
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace         onexbet              1xBet       2.79       3.27       2.73                                                 https://1xbet.com/en/line/football/88637-england-premier-league/279676895-everton-crystal-palace                                                 https://1xbet.com/en/line/football/88637-england-premier-league/279676895-everton-crystal-palace                                                 https://1xbet.com/en/line/football/88637-england-premier-league/279676895-everton-crystal-palace         24.906609
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma     betonlineag       BetOnline.ag       3.13       3.14       2.51                                                                             https://sports.betonline.ag/sportsbook/soccer/serie-a/game/490822741                                                                             https://sports.betonline.ag/sportsbook/soccer/serie-a/game/490822741                                                                             https://sports.betonline.ag/sportsbook/soccer/serie-a/game/490822741         24.668782
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma    betanysports        BetAnything       3.13       3.14       2.51                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         24.668782
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma     marathonbet       Marathon Bet       3.08       3.28       2.44                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         24.649856
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace     betonlineag       BetOnline.ag       2.72       3.13       2.88                                                                                 https://sports.betonline.ag/sportsbook/soccer/epl/game/490822712                                                                                 https://sports.betonline.ag/sportsbook/soccer/epl/game/490822712                                                                                 https://sports.betonline.ag/sportsbook/soccer/epl/game/490822712         24.519168
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma         betsson            Betsson       3.10       3.20       2.45            https://www.betsson.com/en/sportsbook/football/italy/italy-serie-a?tab=liveAndUpcoming&eventId=f-AQXu-Fe9lEmbZ_JYp3usWQ&eti=0&fs=true            https://www.betsson.com/en/sportsbook/football/italy/italy-serie-a?tab=liveAndUpcoming&eventId=f-AQXu-Fe9lEmbZ_JYp3usWQ&eti=0&fs=true            https://www.betsson.com/en/sportsbook/football/italy/italy-serie-a?tab=liveAndUpcoming&eventId=f-AQXu-Fe9lEmbZ_JYp3usWQ&eti=0&fs=true         24.304000
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma       nordicbet         Nordic Bet       3.10       3.20       2.45                                                             https://www.nordicbet.com/en/sportsbook/football/italy/italy-serie-a/fiorentina-roma                                                             https://www.nordicbet.com/en/sportsbook/football/italy/italy-serie-a/fiorentina-roma                                                             https://www.nordicbet.com/en/sportsbook/football/italy/italy-serie-a/fiorentina-roma         24.304000
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz       suprabets          Suprabets       2.90       3.10       2.70                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         24.273000
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace     marathonbet       Marathon Bet       2.72       3.12       2.86                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         24.271104
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace     leovegas_se      LeoVegas (SE)       2.75       3.20       2.75                                                                                          https://www.leovegas.com/sv-se/betting#event/1024043905                                                                                          https://www.leovegas.com/sv-se/betting#event/1024043905                                                                                          https://www.leovegas.com/sv-se/betting#event/1024043905         24.200000
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma      winamax_de       Winamax (DE)       3.05       3.20       2.45                                                                                          https://www.winamax.de/en/sports-betting/match/61060811                                                                                          https://www.winamax.de/en/sports-betting/match/61060811                                                                                          https://www.winamax.de/en/sports-betting/match/61060811         23.912000
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace          gtbets             GTbets       2.68       3.18       2.79                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         23.777496
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma          gtbets             GTbets       3.01       3.21       2.46                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         23.768766
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma       everygame          Everygame       3.10       3.10       2.45                                                          https://sports.everygame.eu/en/Bets/Soccer/Italian-Serie-A/Fiorentina-v-AS-Roma/2719903                                                          https://sports.everygame.eu/en/Bets/Soccer/Italian-Serie-A/Fiorentina-v-AS-Roma/2719903                                                          https://sports.everygame.eu/en/Bets/Soccer/Italian-Serie-A/Fiorentina-v-AS-Roma/2719903         23.544500
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace      mybookieag        MyBookie.ag       2.65       3.16       2.81                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         23.530940
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace       everygame          Everygame       2.65       3.10       2.85                                               https://sports.everygame.eu/en/Bets/Soccer/English-Premier-League/Everton-v-Crystal-Palace/2719876                                               https://sports.everygame.eu/en/Bets/Soccer/English-Premier-League/Everton-v-Crystal-Palace/2719876                                               https://sports.everygame.eu/en/Bets/Soccer/English-Premier-League/Everton-v-Crystal-Palace/2719876         23.412750
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace       unibet_it        Unibet (IT)       2.70       3.15       2.75                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         23.388750
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma       unibet_it        Unibet (IT)       3.05       3.15       2.43                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         23.346225
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace      winamax_de       Winamax (DE)       2.65       3.20       2.75                                                                                          https://www.winamax.de/en/sports-betting/match/61300637                                                                                          https://www.winamax.de/en/sports-betting/match/61300637                                                                                          https://www.winamax.de/en/sports-betting/match/61300637         23.320000
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace         betsson            Betsson       2.65       3.05       2.85 https://www.betsson.com/en/sportsbook/football/england/england-premier-league?tab=liveAndUpcoming&eventId=f-wR9YfsnsPECSJ4tnDx5k8Q&eti=0&fs=true https://www.betsson.com/en/sportsbook/football/england/england-premier-league?tab=liveAndUpcoming&eventId=f-wR9YfsnsPECSJ4tnDx5k8Q&eti=0&fs=true https://www.betsson.com/en/sportsbook/football/england/england-premier-league?tab=liveAndUpcoming&eventId=f-wR9YfsnsPECSJ4tnDx5k8Q&eti=0&fs=true         23.035125
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace       nordicbet         Nordic Bet       2.65       3.05       2.85                                           https://www.nordicbet.com/en/sportsbook/football/england/england-premier-league/everton-crystal-palace                                           https://www.nordicbet.com/en/sportsbook/football/england/england-premier-league/everton-crystal-palace                                           https://www.nordicbet.com/en/sportsbook/football/england/england-premier-league/everton-crystal-palace         23.035125
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace       tipico_de             Tipico       2.65       3.00       2.85                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         22.657500
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace     williamhill       William Hill       2.60       3.10       2.80                                                    https://sports.williamhill.com/betting/en-gb/football/OB_EV37086022/everton-vs-crystal-palace                                                    https://sports.williamhill.com/betting/en-gb/football/OB_EV37086022/everton-vs-crystal-palace                                                    https://sports.williamhill.com/betting/en-gb/football/OB_EV37086022/everton-vs-crystal-palace         22.568000
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace        sport888           888sport       2.60       3.10       2.80                                            https://www.888sport.com/football/england/english-premier-league/everton-vs-crystal-palace-e-6411775/                                            https://www.888sport.com/football/england/english-premier-league/everton-vs-crystal-palace-e-6411775/                                            https://www.888sport.com/football/england/english-premier-league/everton-vs-crystal-palace-e-6411775/         22.568000
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz        pinnacle           Pinnacle       2.90       2.84       2.73                                                       https://www.pinnacle.com/en/soccer/austria-bundesliga/sturm-graz-vs-scr-altach/1617005359/                                                       https://www.pinnacle.com/en/soccer/austria-bundesliga/sturm-graz-vs-scr-altach/1617005359/                                                       https://www.pinnacle.com/en/soccer/austria-bundesliga/sturm-graz-vs-scr-altach/1617005359/         22.484280
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz       unibet_nl        Unibet (NL)       3.00       2.88       2.60                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         22.464000
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz       unibet_se        Unibet (SE)       3.00       2.88       2.60                                                                                            https://www.unibet.se/betting/sports/event/1024139025                                                                                            https://www.unibet.se/betting/sports/event/1024139025                                                                                            https://www.unibet.se/betting/sports/event/1024139025         22.464000
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz       unibet_it        Unibet (IT)       3.00       2.90       2.55                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         22.185000
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma        sport888           888sport       2.90       3.10       2.45                                                            https://www.888sport.com/football/italy/italian-serie-a/fiorentina-vs-roma-e-6449495/                                                            https://www.888sport.com/football/italy/italian-serie-a/fiorentina-vs-roma-e-6449495/                                                            https://www.888sport.com/football/italy/italian-serie-a/fiorentina-vs-roma-e-6449495/         22.025500
# 9c2eb7c53fbd864220cd1181ba14fe4d      soccer_italy_serie_a 2025-10-05T13:00:00Z       Fiorentina        AS Roma     williamhill       William Hill       2.90       3.10       2.45                                                           https://sports.williamhill.com/betting/en-gb/football/OB_EV37166638/fiorentina-vs-roma                                                           https://sports.williamhill.com/betting/en-gb/football/OB_EV37166638/fiorentina-vs-roma                                                           https://sports.williamhill.com/betting/en-gb/football/OB_EV37166638/fiorentina-vs-roma         22.025500
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz         coolbet            Coolbet       2.88       2.75       2.75                                                                                                  https://www.coolbet.com/en/sports/match/4453966                                                                                                  https://www.coolbet.com/en/sports/match/4453966                                                                                                  https://www.coolbet.com/en/sports/match/4453966         21.780000
# c625878da7e09846e8c9e30d83f65f36      soccer_italy_serie_b 2025-10-05T13:00:00Z        Carrarese    Juve Stabia     betonlineag       BetOnline.ag       2.47       2.91       3.00                                                                               https://sports.betonline.ag/sportsbook/soccer/italy/game/490836346                                                                               https://sports.betonline.ag/sportsbook/soccer/italy/game/490836346                                                                               https://sports.betonline.ag/sportsbook/soccer/italy/game/490836346         21.563100
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz       tipico_de             Tipico       3.00       2.70       2.60                                                                                                                                             None                                                                                                                                             None                                                                                                                                             None         21.060000
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace      winamax_fr       Winamax (FR)       2.55       3.10       2.65                                                                                          https://www.winamax.fr/en/sports-betting/match/61300637                                                                                          https://www.winamax.fr/en/sports-betting/match/61300637                                                                                          https://www.winamax.fr/en/sports-betting/match/61300637         20.948250
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace      betclic_fr       Betclic (FR)       2.43       3.08       2.75                                         https://www.betclic.fr/football-sfootball/angl-premier-league-c3/everton-crystal-palace-m814784975048704                                         https://www.betclic.fr/football-sfootball/angl-premier-league-c3/everton-crystal-palace-m814784975048704                                         https://www.betclic.fr/football-sfootball/angl-premier-league-c3/everton-crystal-palace-m814784975048704         20.582100
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace       unibet_fr        Unibet (FR)       2.46       3.05       2.72                                                                 https://www.unibet.fr/sport/football/event/everton-crystal-palace-3291303_1.html                                                                 https://www.unibet.fr/sport/football/event/everton-crystal-palace-3291303_1.html                                                                 https://www.unibet.fr/sport/football/event/everton-crystal-palace-3291303_1.html         20.408160
# 1a7d9a230fc5e77b5fbf420993a8eb93                soccer_epl 2025-10-05T13:00:00Z          Everton Crystal Palace parionssport_fr Parions Sport (FR)       2.55       2.95       2.70                               https://www.enligne.parionssport.fdj.fr/paris-football/angleterre/premier-league/3262466/everton-vs-crystal-palace                               https://www.enligne.parionssport.fdj.fr/paris-football/angleterre/premier-league/3262466/everton-vs-crystal-palace                               https://www.enligne.parionssport.fdj.fr/paris-football/angleterre/premier-league/3262466/everton-vs-crystal-palace         20.310750
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz     leovegas_se      LeoVegas (SE)       2.90       2.80       2.50                                                                                          https://www.leovegas.com/sv-se/betting#event/1024139025                                                                                          https://www.leovegas.com/sv-se/betting#event/1024139025                                                                                          https://www.leovegas.com/sv-se/betting#event/1024139025         20.300000
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz      winamax_de       Winamax (DE)       2.80       2.65       2.60                                                                                          https://www.winamax.de/en/sports-betting/match/61518644                                                                                          https://www.winamax.de/en/sports-betting/match/61518644                                                                                          https://www.winamax.de/en/sports-betting/match/61518644         19.292000
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz         betsson            Betsson       2.75       2.68       2.60     https://www.betsson.com/en/sportsbook/football/austria/austria-bundesliga?tab=liveAndUpcoming&eventId=f-9xxHnXgS5kGxa8dFh1mJWg&eti=0&fs=true     https://www.betsson.com/en/sportsbook/football/austria/austria-bundesliga?tab=liveAndUpcoming&eventId=f-9xxHnXgS5kGxa8dFh1mJWg&eti=0&fs=true     https://www.betsson.com/en/sportsbook/football/austria/austria-bundesliga?tab=liveAndUpcoming&eventId=f-9xxHnXgS5kGxa8dFh1mJWg&eti=0&fs=true         19.162000
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz       nordicbet         Nordic Bet       2.75       2.68       2.60                                                 https://www.nordicbet.com/en/sportsbook/football/austria/austria-bundesliga/altach-sk-sturm-graz                                                 https://www.nordicbet.com/en/sportsbook/football/austria/austria-bundesliga/altach-sk-sturm-graz                                                 https://www.nordicbet.com/en/sportsbook/football/austria/austria-bundesliga/altach-sk-sturm-graz         19.162000
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz      winamax_fr       Winamax (FR)       2.65       2.55       2.50                                                                                          https://www.winamax.fr/en/sports-betting/match/61518644                                                                                          https://www.winamax.fr/en/sports-betting/match/61518644                                                                                          https://www.winamax.fr/en/sports-betting/match/61518644         16.893750
# 6da729437080e553fb91c8eb73ad3ae8 soccer_austria_bundesliga 2025-10-05T12:31:00Z Rheindorf Altach     Sturm Graz      betclic_fr       Betclic (FR)       2.65       2.52       2.47                                         https://www.betclic.fr/football-sfootball/autriche-bundesliga-c35/scr-altach-sturm-graz-m823196416880640                                         https://www.betclic.fr/football-sfootball/autriche-bundesliga-c35/scr-altach-sturm-graz-m823196416880640                                         https://www.betclic.fr/football-sfootball/autriche-bundesliga-c35/scr-altach-sturm-graz-m823196416880640         16.494660
#
# Les résultats ont été enregistrés dans le fichier 'data-paris-sportifs.csv'.

# %%
data_paris_sportifs = pd.read_csv("./data/data-paris-sportifs.csv")
data_paris_sportifs
# Out:
#                             event_id                  sport_key  \
# 0   9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 1   9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 2   1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 3   1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 4   1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 5   9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 6   1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 7   1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 8   6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 9   9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 10  c625878da7e09846e8c9e30d83f65f36       soccer_italy_serie_b
# 11  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 12  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 13  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 14  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 15  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 16  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 17  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 18  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 19  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 20  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 21  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 22  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 23  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 24  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 25  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 26  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 27  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 28  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 29  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 30  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 31  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 32  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 33  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 34  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 35  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 36  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 37  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 38  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 39  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 40  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 41  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 42  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 43  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 44  9c2eb7c53fbd864220cd1181ba14fe4d       soccer_italy_serie_a
# 45  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 46  c625878da7e09846e8c9e30d83f65f36       soccer_italy_serie_b
# 47  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 48  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 49  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 50  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 51  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 52  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 53  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 54  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 55  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 56  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 57  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
#
#            commence_time         home_team       away_team        bookmaker  \
# 0   2025-10-05T13:00:00Z        Fiorentina         AS Roma    betfair_ex_eu
# 1   2025-10-05T13:00:00Z        Fiorentina         AS Roma        matchbook
# 2   2025-10-05T13:00:00Z           Everton  Crystal Palace    betfair_ex_eu
# 3   2025-10-05T13:00:00Z           Everton  Crystal Palace        matchbook
# 4   2025-10-05T13:00:00Z           Everton  Crystal Palace          coolbet
# 5   2025-10-05T13:00:00Z        Fiorentina         AS Roma         pinnacle
# 6   2025-10-05T13:00:00Z           Everton  Crystal Palace        unibet_se
# 7   2025-10-05T13:00:00Z           Everton  Crystal Palace        unibet_nl
# 8   2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz    betfair_ex_eu
# 9   2025-10-05T13:00:00Z        Fiorentina         AS Roma          coolbet
# 10  2025-10-05T13:00:00Z         Carrarese     Juve Stabia         pinnacle
# 11  2025-10-05T13:00:00Z        Fiorentina         AS Roma          onexbet
# 12  2025-10-05T13:00:00Z        Fiorentina         AS Roma        unibet_se
# 13  2025-10-05T13:00:00Z        Fiorentina         AS Roma        unibet_nl
# 14  2025-10-05T13:00:00Z           Everton  Crystal Palace         pinnacle
# 15  2025-10-05T13:00:00Z           Everton  Crystal Palace          onexbet
# 16  2025-10-05T13:00:00Z        Fiorentina         AS Roma      betonlineag
# 17  2025-10-05T13:00:00Z        Fiorentina         AS Roma     betanysports
# 18  2025-10-05T13:00:00Z        Fiorentina         AS Roma      marathonbet
# 19  2025-10-05T13:00:00Z           Everton  Crystal Palace      betonlineag
# 20  2025-10-05T13:00:00Z        Fiorentina         AS Roma          betsson
# 21  2025-10-05T13:00:00Z        Fiorentina         AS Roma        nordicbet
# 22  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz        suprabets
# 23  2025-10-05T13:00:00Z           Everton  Crystal Palace      marathonbet
# 24  2025-10-05T13:00:00Z           Everton  Crystal Palace      leovegas_se
# 25  2025-10-05T13:00:00Z        Fiorentina         AS Roma       winamax_de
# 26  2025-10-05T13:00:00Z           Everton  Crystal Palace           gtbets
# 27  2025-10-05T13:00:00Z        Fiorentina         AS Roma           gtbets
# 28  2025-10-05T13:00:00Z        Fiorentina         AS Roma        everygame
# 29  2025-10-05T13:00:00Z           Everton  Crystal Palace       mybookieag
# 30  2025-10-05T13:00:00Z           Everton  Crystal Palace        everygame
# 31  2025-10-05T13:00:00Z           Everton  Crystal Palace        unibet_it
# 32  2025-10-05T13:00:00Z        Fiorentina         AS Roma        unibet_it
# 33  2025-10-05T13:00:00Z           Everton  Crystal Palace       winamax_de
# 34  2025-10-05T13:00:00Z           Everton  Crystal Palace          betsson
# 35  2025-10-05T13:00:00Z           Everton  Crystal Palace        nordicbet
# 36  2025-10-05T13:00:00Z           Everton  Crystal Palace        tipico_de
# 37  2025-10-05T13:00:00Z           Everton  Crystal Palace      williamhill
# 38  2025-10-05T13:00:00Z           Everton  Crystal Palace         sport888
# 39  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz         pinnacle
# 40  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz        unibet_nl
# 41  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz        unibet_se
# 42  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz        unibet_it
# 43  2025-10-05T13:00:00Z        Fiorentina         AS Roma         sport888
# 44  2025-10-05T13:00:00Z        Fiorentina         AS Roma      williamhill
# 45  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz          coolbet
# 46  2025-10-05T13:00:00Z         Carrarese     Juve Stabia      betonlineag
# 47  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz        tipico_de
# 48  2025-10-05T13:00:00Z           Everton  Crystal Palace       winamax_fr
# 49  2025-10-05T13:00:00Z           Everton  Crystal Palace       betclic_fr
# 50  2025-10-05T13:00:00Z           Everton  Crystal Palace        unibet_fr
# 51  2025-10-05T13:00:00Z           Everton  Crystal Palace  parionssport_fr
# 52  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz      leovegas_se
# 53  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz       winamax_de
# 54  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz          betsson
# 55  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz        nordicbet
# 56  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz       winamax_fr
# 57  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz       betclic_fr
#
#        bookmaker_title  home_odds  draw_odds  away_odds  \
# 0              Betfair       3.30       3.20       2.58
# 1            Matchbook       3.30       3.20       2.56
# 2              Betfair       2.80       3.20       2.98
# 3            Matchbook       2.80       3.20       2.98
# 4              Coolbet       2.77       3.18       2.90
# 5             Pinnacle       3.25       3.19       2.46
# 6          Unibet (SE)       2.80       3.25       2.80
# 7          Unibet (NL)       2.80       3.25       2.80
# 8              Betfair       3.15       2.82       2.84
# 9              Coolbet       3.20       3.15       2.50
# 10            Pinnacle       2.46       2.96       3.45
# 11               1xBet       3.06       3.27       2.50
# 12         Unibet (SE)       3.15       3.20       2.48
# 13         Unibet (NL)       3.15       3.20       2.48
# 14            Pinnacle       2.72       3.14       2.92
# 15               1xBet       2.79       3.27       2.73
# 16        BetOnline.ag       3.13       3.14       2.51
# 17         BetAnything       3.13       3.14       2.51
# 18        Marathon Bet       3.08       3.28       2.44
# 19        BetOnline.ag       2.72       3.13       2.88
# 20             Betsson       3.10       3.20       2.45
# 21          Nordic Bet       3.10       3.20       2.45
# 22           Suprabets       2.90       3.10       2.70
# 23        Marathon Bet       2.72       3.12       2.86
# 24       LeoVegas (SE)       2.75       3.20       2.75
# 25        Winamax (DE)       3.05       3.20       2.45
# 26              GTbets       2.68       3.18       2.79
# 27              GTbets       3.01       3.21       2.46
# 28           Everygame       3.10       3.10       2.45
# 29         MyBookie.ag       2.65       3.16       2.81
# 30           Everygame       2.65       3.10       2.85
# 31         Unibet (IT)       2.70       3.15       2.75
# 32         Unibet (IT)       3.05       3.15       2.43
# 33        Winamax (DE)       2.65       3.20       2.75
# 34             Betsson       2.65       3.05       2.85
# 35          Nordic Bet       2.65       3.05       2.85
# 36              Tipico       2.65       3.00       2.85
# 37        William Hill       2.60       3.10       2.80
# 38            888sport       2.60       3.10       2.80
# 39            Pinnacle       2.90       2.84       2.73
# 40         Unibet (NL)       3.00       2.88       2.60
# 41         Unibet (SE)       3.00       2.88       2.60
# 42         Unibet (IT)       3.00       2.90       2.55
# 43            888sport       2.90       3.10       2.45
# 44        William Hill       2.90       3.10       2.45
# 45             Coolbet       2.88       2.75       2.75
# 46        BetOnline.ag       2.47       2.91       3.00
# 47              Tipico       3.00       2.70       2.60
# 48        Winamax (FR)       2.55       3.10       2.65
# 49        Betclic (FR)       2.43       3.08       2.75
# 50         Unibet (FR)       2.46       3.05       2.72
# 51  Parions Sport (FR)       2.55       2.95       2.70
# 52       LeoVegas (SE)       2.90       2.80       2.50
# 53        Winamax (DE)       2.80       2.65       2.60
# 54             Betsson       2.75       2.68       2.60
# 55          Nordic Bet       2.75       2.68       2.60
# 56        Winamax (FR)       2.65       2.55       2.50
# 57        Betclic (FR)       2.65       2.52       2.47
#
#                                             home_link  \
# 0   https://www.betfair.com/exchange/plus/football...
# 1   https://www.matchbook.com/events/soccer/italy/...
# 2   https://www.betfair.com/exchange/plus/football...
# 3   https://www.matchbook.com/events/soccer/englan...
# 4     https://www.coolbet.com/en/sports/match/4420209
# 5   https://www.pinnacle.com/en/soccer/italy-serie...
# 6   https://www.unibet.se/betting/sports/event/102...
# 7                                                 NaN
# 8   https://www.betfair.com/exchange/plus/football...
# 9     https://www.coolbet.com/en/sports/match/4424966
# 10  https://www.pinnacle.com/en/soccer/italy-serie...
# 11  https://1xbet.com/en/line/football/110163-ital...
# 12  https://www.unibet.se/betting/sports/event/102...
# 13                                                NaN
# 14  https://www.pinnacle.com/en/soccer/england-pre...
# 15  https://1xbet.com/en/line/football/88637-engla...
# 16  https://sports.betonline.ag/sportsbook/soccer/...
# 17                                                NaN
# 18                                                NaN
# 19  https://sports.betonline.ag/sportsbook/soccer/...
# 20  https://www.betsson.com/en/sportsbook/football...
# 21  https://www.nordicbet.com/en/sportsbook/footba...
# 22                                                NaN
# 23                                                NaN
# 24  https://www.leovegas.com/sv-se/betting#event/1...
# 25  https://www.winamax.de/en/sports-betting/match...
# 26                                                NaN
# 27                                                NaN
# 28  https://sports.everygame.eu/en/Bets/Soccer/Ita...
# 29                                                NaN
# 30  https://sports.everygame.eu/en/Bets/Soccer/Eng...
# 31                                                NaN
# 32                                                NaN
# 33  https://www.winamax.de/en/sports-betting/match...
# 34  https://www.betsson.com/en/sportsbook/football...
# 35  https://www.nordicbet.com/en/sportsbook/footba...
# 36                                                NaN
# 37  https://sports.williamhill.com/betting/en-gb/f...
# 38  https://www.888sport.com/football/england/engl...
# 39  https://www.pinnacle.com/en/soccer/austria-bun...
# 40                                                NaN
# 41  https://www.unibet.se/betting/sports/event/102...
# 42                                                NaN
# 43  https://www.888sport.com/football/italy/italia...
# 44  https://sports.williamhill.com/betting/en-gb/f...
# 45    https://www.coolbet.com/en/sports/match/4453966
# 46  https://sports.betonline.ag/sportsbook/soccer/...
# 47                                                NaN
# 48  https://www.winamax.fr/en/sports-betting/match...
# 49  https://www.betclic.fr/football-sfootball/angl...
# 50  https://www.unibet.fr/sport/football/event/eve...
# 51  https://www.enligne.parionssport.fdj.fr/paris-...
# 52  https://www.leovegas.com/sv-se/betting#event/1...
# 53  https://www.winamax.de/en/sports-betting/match...
# 54  https://www.betsson.com/en/sportsbook/football...
# 55  https://www.nordicbet.com/en/sportsbook/footba...
# 56  https://www.winamax.fr/en/sports-betting/match...
# 57  https://www.betclic.fr/football-sfootball/autr...
#
#                                             draw_link  \
# 0   https://www.betfair.com/exchange/plus/football...
# 1   https://www.matchbook.com/events/soccer/italy/...
# 2   https://www.betfair.com/exchange/plus/football...
# 3   https://www.matchbook.com/events/soccer/englan...
# 4     https://www.coolbet.com/en/sports/match/4420209
# 5   https://www.pinnacle.com/en/soccer/italy-serie...
# 6   https://www.unibet.se/betting/sports/event/102...
# 7                                                 NaN
# 8   https://www.betfair.com/exchange/plus/football...
# 9     https://www.coolbet.com/en/sports/match/4424966
# 10  https://www.pinnacle.com/en/soccer/italy-serie...
# 11  https://1xbet.com/en/line/football/110163-ital...
# 12  https://www.unibet.se/betting/sports/event/102...
# 13                                                NaN
# 14  https://www.pinnacle.com/en/soccer/england-pre...
# 15  https://1xbet.com/en/line/football/88637-engla...
# 16  https://sports.betonline.ag/sportsbook/soccer/...
# 17                                                NaN
# 18                                                NaN
# 19  https://sports.betonline.ag/sportsbook/soccer/...
# 20  https://www.betsson.com/en/sportsbook/football...
# 21  https://www.nordicbet.com/en/sportsbook/footba...
# 22                                                NaN
# 23                                                NaN
# 24  https://www.leovegas.com/sv-se/betting#event/1...
# 25  https://www.winamax.de/en/sports-betting/match...
# 26                                                NaN
# 27                                                NaN
# 28  https://sports.everygame.eu/en/Bets/Soccer/Ita...
# 29                                                NaN
# 30  https://sports.everygame.eu/en/Bets/Soccer/Eng...
# 31                                                NaN
# 32                                                NaN
# 33  https://www.winamax.de/en/sports-betting/match...
# 34  https://www.betsson.com/en/sportsbook/football...
# 35  https://www.nordicbet.com/en/sportsbook/footba...
# 36                                                NaN
# 37  https://sports.williamhill.com/betting/en-gb/f...
# 38  https://www.888sport.com/football/england/engl...
# 39  https://www.pinnacle.com/en/soccer/austria-bun...
# 40                                                NaN
# 41  https://www.unibet.se/betting/sports/event/102...
# 42                                                NaN
# 43  https://www.888sport.com/football/italy/italia...
# 44  https://sports.williamhill.com/betting/en-gb/f...
# 45    https://www.coolbet.com/en/sports/match/4453966
# 46  https://sports.betonline.ag/sportsbook/soccer/...
# 47                                                NaN
# 48  https://www.winamax.fr/en/sports-betting/match...
# 49  https://www.betclic.fr/football-sfootball/angl...
# 50  https://www.unibet.fr/sport/football/event/eve...
# 51  https://www.enligne.parionssport.fdj.fr/paris-...
# 52  https://www.leovegas.com/sv-se/betting#event/1...
# 53  https://www.winamax.de/en/sports-betting/match...
# 54  https://www.betsson.com/en/sportsbook/football...
# 55  https://www.nordicbet.com/en/sportsbook/footba...
# 56  https://www.winamax.fr/en/sports-betting/match...
# 57  https://www.betclic.fr/football-sfootball/autr...
#
#                                             away_link  combined_product
# 0   https://www.betfair.com/exchange/plus/football...         27.244800
# 1   https://www.matchbook.com/events/soccer/italy/...         27.033600
# 2   https://www.betfair.com/exchange/plus/football...         26.700800
# 3   https://www.matchbook.com/events/soccer/englan...         26.700800
# 4     https://www.coolbet.com/en/sports/match/4420209         25.544940
# 5   https://www.pinnacle.com/en/soccer/italy-serie...         25.504050
# 6   https://www.unibet.se/betting/sports/event/102...         25.480000
# 7                                                 NaN         25.480000
# 8   https://www.betfair.com/exchange/plus/football...         25.227720
# 9     https://www.coolbet.com/en/sports/match/4424966         25.200000
# 10  https://www.pinnacle.com/en/soccer/italy-serie...         25.121520
# 11  https://1xbet.com/en/line/football/110163-ital...         25.015500
# 12  https://www.unibet.se/betting/sports/event/102...         24.998400
# 13                                                NaN         24.998400
# 14  https://www.pinnacle.com/en/soccer/england-pre...         24.939136
# 15  https://1xbet.com/en/line/football/88637-engla...         24.906609
# 16  https://sports.betonline.ag/sportsbook/soccer/...         24.668782
# 17                                                NaN         24.668782
# 18                                                NaN         24.649856
# 19  https://sports.betonline.ag/sportsbook/soccer/...         24.519168
# 20  https://www.betsson.com/en/sportsbook/football...         24.304000
# 21  https://www.nordicbet.com/en/sportsbook/footba...         24.304000
# 22                                                NaN         24.273000
# 23                                                NaN         24.271104
# 24  https://www.leovegas.com/sv-se/betting#event/1...         24.200000
# 25  https://www.winamax.de/en/sports-betting/match...         23.912000
# 26                                                NaN         23.777496
# 27                                                NaN         23.768766
# 28  https://sports.everygame.eu/en/Bets/Soccer/Ita...         23.544500
# 29                                                NaN         23.530940
# 30  https://sports.everygame.eu/en/Bets/Soccer/Eng...         23.412750
# 31                                                NaN         23.388750
# 32                                                NaN         23.346225
# 33  https://www.winamax.de/en/sports-betting/match...         23.320000
# 34  https://www.betsson.com/en/sportsbook/football...         23.035125
# 35  https://www.nordicbet.com/en/sportsbook/footba...         23.035125
# 36                                                NaN         22.657500
# 37  https://sports.williamhill.com/betting/en-gb/f...         22.568000
# 38  https://www.888sport.com/football/england/engl...         22.568000
# 39  https://www.pinnacle.com/en/soccer/austria-bun...         22.484280
# 40                                                NaN         22.464000
# 41  https://www.unibet.se/betting/sports/event/102...         22.464000
# 42                                                NaN         22.185000
# 43  https://www.888sport.com/football/italy/italia...         22.025500
# 44  https://sports.williamhill.com/betting/en-gb/f...         22.025500
# 45    https://www.coolbet.com/en/sports/match/4453966         21.780000
# 46  https://sports.betonline.ag/sportsbook/soccer/...         21.563100
# 47                                                NaN         21.060000
# 48  https://www.winamax.fr/en/sports-betting/match...         20.948250
# 49  https://www.betclic.fr/football-sfootball/angl...         20.582100
# 50  https://www.unibet.fr/sport/football/event/eve...         20.408160
# 51  https://www.enligne.parionssport.fdj.fr/paris-...         20.310750
# 52  https://www.leovegas.com/sv-se/betting#event/1...         20.300000
# 53  https://www.winamax.de/en/sports-betting/match...         19.292000
# 54  https://www.betsson.com/en/sportsbook/football...         19.162000
# 55  https://www.nordicbet.com/en/sportsbook/footba...         19.162000
# 56  https://www.winamax.fr/en/sports-betting/match...         16.893750
# 57  https://www.betclic.fr/football-sfootball/autr...         16.494660

# %%
# Filtrer le dataframe pour afficher uniquement les bookmakers français (contenant '(FR)' dans 'bookmaker_title')
df_paris_sportifs_fr = data_paris_sportifs[data_paris_sportifs['bookmaker_title'].str.contains(r'\(FR\)', na=False)]
df_paris_sportifs_fr
# Out:
#                             event_id                  sport_key  \
# 48  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 49  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 50  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 51  1a7d9a230fc5e77b5fbf420993a8eb93                 soccer_epl
# 56  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
# 57  6da729437080e553fb91c8eb73ad3ae8  soccer_austria_bundesliga
#
#            commence_time         home_team       away_team        bookmaker  \
# 48  2025-10-05T13:00:00Z           Everton  Crystal Palace       winamax_fr
# 49  2025-10-05T13:00:00Z           Everton  Crystal Palace       betclic_fr
# 50  2025-10-05T13:00:00Z           Everton  Crystal Palace        unibet_fr
# 51  2025-10-05T13:00:00Z           Everton  Crystal Palace  parionssport_fr
# 56  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz       winamax_fr
# 57  2025-10-05T12:31:00Z  Rheindorf Altach      Sturm Graz       betclic_fr
#
#        bookmaker_title  home_odds  draw_odds  away_odds  \
# 48        Winamax (FR)       2.55       3.10       2.65
# 49        Betclic (FR)       2.43       3.08       2.75
# 50         Unibet (FR)       2.46       3.05       2.72
# 51  Parions Sport (FR)       2.55       2.95       2.70
# 56        Winamax (FR)       2.65       2.55       2.50
# 57        Betclic (FR)       2.65       2.52       2.47
#
#                                             home_link  \
# 48  https://www.winamax.fr/en/sports-betting/match...
# 49  https://www.betclic.fr/football-sfootball/angl...
# 50  https://www.unibet.fr/sport/football/event/eve...
# 51  https://www.enligne.parionssport.fdj.fr/paris-...
# 56  https://www.winamax.fr/en/sports-betting/match...
# 57  https://www.betclic.fr/football-sfootball/autr...
#
#                                             draw_link  \
# 48  https://www.winamax.fr/en/sports-betting/match...
# 49  https://www.betclic.fr/football-sfootball/angl...
# 50  https://www.unibet.fr/sport/football/event/eve...
# 51  https://www.enligne.parionssport.fdj.fr/paris-...
# 56  https://www.winamax.fr/en/sports-betting/match...
# 57  https://www.betclic.fr/football-sfootball/autr...
#
#                                             away_link  combined_product
# 48  https://www.winamax.fr/en/sports-betting/match...          20.94825
# 49  https://www.betclic.fr/football-sfootball/angl...          20.58210
# 50  https://www.unibet.fr/sport/football/event/eve...          20.40816
# 51  https://www.enligne.parionssport.fdj.fr/paris-...          20.31075
# 56  https://www.winamax.fr/en/sports-betting/match...          16.89375
# 57  https://www.betclic.fr/football-sfootball/autr...          16.49466
